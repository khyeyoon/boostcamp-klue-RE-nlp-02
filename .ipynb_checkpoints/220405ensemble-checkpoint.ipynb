# %%
import numpy as np
import pandas as pd
from glob import glob
import pickle as pickle

# %%
# !pwd
# Out:
# /opt/ml/week12

# %%
# csv 파일들 저장한 위치
outputs = glob('/opt/ml/week12/submission_csv/*')
print(len(outputs))
print(outputs)
# Out:
# 10
# ['/opt/ml/week12/submission_csv/output (9).csv', '/opt/ml/week12/submission_csv/output (7).csv', '/opt/ml/week12/submission_csv/output (8).csv', '/opt/ml/week12/submission_csv/output (5).csv', '/opt/ml/week12/submission_csv/output (2).csv', '/opt/ml/week12/submission_csv/output (4).csv', '/opt/ml/week12/submission_csv/output.csv', '/opt/ml/week12/submission_csv/output (1).csv', '/opt/ml/week12/submission_csv/output (6).csv', '/opt/ml/week12/submission_csv/output (3).csv']

# %%
new_input = list()
for output in outputs:
    df = pd.read_csv(output)
    new_input.append(list(df['probs']))
new_input = np.transpose(new_input)
new_input.shape
# Out:
# (7765, 10)

# %%
print(new_input[0])
print(type(new_input[0]))
# Out:
# ['[0.32713833451271057, 0.02355446293950081, 0.14869093894958496, 0.25416767597198486, 0.0007471737917512655, 0.20028157532215118, 0.0007402737392112613, 0.007639969699084759, 0.011262004263699055, 0.001323570730164647, 0.0003071780956815928, 0.00015975828864611685, 0.0028656786307692528, 0.0003488463698886335, 0.000115520553663373, 0.000172675252542831, 0.00013978294737171382, 0.0003045243793167174, 0.0013292100047692657, 0.005139508284628391, 0.004079839214682579, 0.00016616765060462058, 0.0008072055643424392, 0.00016692496137693524, 7.146794814616442e-05, 9.923533798428252e-05, 9.082807810045779e-05, 0.00014772337453905493, 0.00766321225091815, 0.00027880974812433124]'
#  '[0.2236699014902115, 0.014025803655385971, 0.15913185477256775, 0.499051570892334, 0.0017946111038327217, 0.03024592250585556, 0.0008877114159986377, 0.002757586073130369, 0.003107165452092886, 0.0028308634646236897, 0.0010672033531591296, 0.0004226871533319354, 0.0018489736830815673, 0.0015734549378976226, 0.0006660991348326206, 0.0006981348851695657, 0.0014093273784965277, 0.0012027038028463721, 0.0038932596798986197, 0.010567163117229939, 0.02132011391222477, 0.0019895019941031933, 0.002208648482337594, 0.0012092988472431898, 0.0013287641340866685, 0.0029097525402903557, 0.0012584717478603125, 0.0015792946796864271, 0.0033825950231403112, 0.001961486879736185]'
#  '[0.1645236611366272, 0.0066846865229308605, 0.4109727442264557, 0.35048189759254456, 0.001345184282399714, 0.011310369707643986, 0.00236958684399724, 0.01685933955013752, 0.0036202643532305956, 0.004478146322071552, 0.0009500582236796618, 0.005128891207277775, 0.0008686013170517981, 0.0001705565518932417, 0.0006708861328661442, 0.0008472397457808256, 0.0004956212942488492, 0.0002676721487659961, 0.00018738135986495763, 0.0018481536535546184, 0.006924788933247328, 0.000561571039725095, 0.0031663142144680023, 0.0005674174171872437, 0.0007119717192836106, 0.0011309442343190312, 0.0008636633865535259, 0.0005173543468117714, 0.0013067619875073433, 0.00016820609744172543]'
#  '[0.2846234440803528, 0.017630932852625847, 0.10798508673906326, 0.5260043740272522, 0.0013863160274922848, 0.025481820106506348, 0.0025692430790513754, 0.003848270745947957, 0.004039749503135681, 0.0008809725404717028, 0.0011439963709563017, 0.0008281884365715086, 0.0014589085476472974, 0.000735273293685168, 0.0008651854004710913, 0.0007104702526703477, 0.0006867600022815168, 0.0006710488814860582, 0.000869634619448334, 0.001975727966055274, 0.006739497184753418, 0.0010243385331705213, 0.0006452829693444073, 0.0005305415252223611, 0.0007372259278781712, 0.0008224028279073536, 0.0003968018863815814, 0.0005101950955577195, 0.0036493137013167143, 0.0005490261246450245]'
#  '[0.2484281212091446, 0.014939351007342339, 0.5756620764732361, 0.0789855346083641, 0.0006728525040671229, 0.030942082405090332, 0.0010438417084515095, 0.010382067412137985, 0.0013637522934004664, 0.0028484459035098553, 0.0010267209727317095, 0.0006901461747474968, 0.0008335087331943214, 0.0010974095202982426, 0.0008741430356167257, 0.0006243853131309152, 0.0008959306869655848, 0.0005932027124799788, 0.001142307766713202, 0.005799087695777416, 0.012969681061804295, 0.0005596059490926564, 0.0009982589399442077, 0.0005512309726327658, 0.001102643320336938, 0.0007445369265042245, 0.0005481231492012739, 0.0006882069283165038, 0.0023484884295612574, 0.0006442588637582958]']
# <class 'numpy.ndarray'>

# %%
len(new_input)
# Out:
# 7765

# %%
# 각 csv 파일의 같은 문장에 대한 확률값 모두 뽑아오기
ans_list = list()
for row_data in new_input:
    # str로 뭉쳐져 있는 데이터를 np로 split
    row_data = np.split(row_data, len(row_data))
    
    # 클래스 갯수는 30개
    class_num = 30
    # 30개 클래스 값을 단순 누적으로 더할 list 선언
    temp_list = [0] * class_num
    # n개의 csv 파일에 대해 탐색
    for i in range(len(row_data)):
        # str 데이터를 list 형태로 변환
        temp_data = row_data[i][0].replace('[', '').replace(']', '').strip().split(', ')
        # 각 값마다 알맞은 class의 확률 값에 더해줌
        for idx, temp in enumerate(temp_data):
            temp_list[idx] += float(temp)
    
    # 단순 누적한 합을 csv파일 갯수로 나누어 평균을 구함.
    row_len = len(row_data)
    for i in range(class_num):
        temp_list[i] /= row_len
    
    ans_list.append(temp_list[:])

for i in range(2):
    print(ans_list[i])
    print(sum(ans_list[i]))
# Out:
# [0.2265540361404419, 0.013403923390433193, 0.2920028369873762, 0.35332113727927206, 0.0010391354328021408, 0.0660822482779622, 0.0013855094090104102, 0.007252805074676872, 0.0032114589121192694, 0.0018321973097044975, 0.0013039801240665838, 0.0010578019195236267, 0.001341211935505271, 0.0008118748039123603, 0.0006110078189522028, 0.0006071363903174642, 0.0007562161204987206, 0.0006944809618289582, 0.001454490867035929, 0.005555232148617506, 0.010863143135793507, 0.0007308946733246557, 0.0011634980328381062, 0.0005442114328616299, 0.0006427776461350732, 0.0009013165290525649, 0.0005542061233427375, 0.0006293131489655934, 0.0029474620707333086, 0.000744441086135339]
# 0.9999999851832401
# [0.14024111852049828, 0.0019009432347957046, 0.0008724756189621985, 0.001530211343197152, 0.22578449472784995, 0.007169236557092518, 0.015247190929949283, 0.0012916003091959284, 0.00682969824410975, 0.0005208500981098041, 0.004090648129931651, 0.002595094253774732, 0.5342194586992264, 0.003296414372744039, 0.003626798721961677, 0.009855606290511788, 0.00337997549213469, 0.013065017038024962, 0.0008634399011498318, 0.0004802854178706184, 0.0014357564272359014, 0.011452658171765506, 0.0003863056525005959, 0.0008719354547793046, 0.0011204941663891077, 0.002113542938604951, 0.0032590358052402733, 0.0007469587726518512, 0.0008140499034198001, 0.0009387002704897895]
# 0.9999999954641681

# %%
print(len(ans_list))
# Out:
# 7765

# %%
def num_to_label(label):
    num_label = []
    with open('dict_num_to_label.pkl', 'rb') as f:
        dict_num_to_label = pickle.load(f)
    for v in label:
        num_label.append(dict_num_to_label[v.index(max(v))])
    
    return num_label

# %%
print(dict_num_to_label)
# Out:
# {0: 'no_relation', 1: 'org:top_members/employees', 2: 'org:members', 3: 'org:product', 4: 'per:title', 5: 'org:alternate_names', 6: 'per:employee_of', 7: 'org:place_of_headquarters', 8: 'per:product', 9: 'org:number_of_employees/members', 10: 'per:children', 11: 'per:place_of_residence', 12: 'per:alternate_names', 13: 'per:other_family', 14: 'per:colleagues', 15: 'per:origin', 16: 'per:siblings', 17: 'per:spouse', 18: 'org:founded', 19: 'org:political/religious_affiliation', 20: 'org:member_of', 21: 'per:parents', 22: 'org:dissolved', 23: 'per:schools_attended', 24: 'per:date_of_death', 25: 'per:date_of_birth', 26: 'per:place_of_birth', 27: 'per:place_of_death', 28: 'org:founded_by', 29: 'per:religion'}

# %%
pred_list = num_to_label(ans_list)
print(pred_list[:10])
# Out:
# ['org:product', 'per:alternate_names', 'no_relation', 'no_relation', 'no_relation', 'no_relation', 'per:employee_of', 'per:spouse', 'org:members', 'org:top_members/employees']

# %%
submission = pd.read_csv('info.csv')
submission['pred_label'] = pred_list
submission['probs'] = ans_list
print(submission)

submission.to_csv('./soft_voting.csv', index=False)
# Out:
#         id                 pred_label  \
# 0        0                org:product
# 1        1        per:alternate_names
# 2        2                no_relation
# 3        3                no_relation
# 4        4                no_relation
# ...    ...                        ...
# 7760  7760  org:place_of_headquarters
# 7761  7761                no_relation
# 7762  7762  org:top_members/employees
# 7763  7763                no_relation
# 7764  7764                no_relation
#
#                                                   probs
# 0     [0.2265540361404419, 0.013403923390433193, 0.2...
# 1     [0.14024111852049828, 0.0019009432347957046, 0...
# 2     [0.926885062456131, 0.0007906066894065589, 0.0...
# 3     [0.7138916432857514, 0.0012688107264693827, 0....
# 4     [0.4990161508321762, 0.4744394689798355, 0.002...
# ...                                                 ...
# 7760  [0.3600618988275528, 0.004749962675850839, 0.0...
# 7761  [0.9263877034187317, 0.005165117891738191, 0.0...
# 7762  [0.02454899491276592, 0.9562771797180176, 0.00...
# 7763  [0.7994910657405854, 0.0010338587599107996, 0....
# 7764  [0.9373302221298218, 0.0025942673299141463, 0....
#
# [7765 rows x 3 columns]
